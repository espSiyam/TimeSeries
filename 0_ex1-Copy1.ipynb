# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sample =  np.random.normal(size = 1000)

# %%
plt.hist(sample, bins = 22)
plt.show()

# %%
plt.plot(sample)
plt.show()

# %%
import pandas as pd
df = pd.DataFrame(sample)

# %%
df.plot()
plt.show()
